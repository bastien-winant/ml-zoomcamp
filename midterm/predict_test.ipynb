# %%
import requests

# %%
url = "http://localhost:9696/predict"

# %%
expedition = {
	'year': 2006,
	'season': 'Autumn',
	'host': 'China',
	'nation': 'Italy',
	'camps': 2,
	'totmembers': 1,
	'tothired': 0,
	'o2climb': False,
	'o2descent': False,
	'o2sleep': False,
	'comrte': True,
	'stdrte': True,
	'primrte': False,
	'sponsored': True,
	'ascent_route': 'CHOY-NW_side',
	'total_experience': 15,
	'total_leadership_experience': 8,
	'total_successes': 10,
	'avg_climber_age': 57.0,
	'leaders': 1,
	'support': 0,
	'disabled': 0,
	'hired': 0,
	'sherpas': 0
}

# %%
response = requests.post(url, json=expedition).json()

# %%
response
# Out:
# {'failure': False, 'failure_probability': 0.35}
